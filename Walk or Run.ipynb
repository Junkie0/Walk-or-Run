# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# import the data
walk_run = pd.read_csv("dataset.csv")
walk_run.head(5)
# Out:
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %%
walk_run.describe()
# Out:
#               wrist      activity  acceleration_x  acceleration_y  \
# count  88588.000000  88588.000000    88588.000000    88588.000000
# mean       0.522170      0.500801       -0.074811       -0.562585
# std        0.499511      0.500002        1.009299        0.658458
# min        0.000000      0.000000       -5.350500       -3.299000
# 25%        0.000000      0.000000       -0.381800       -1.033500
# 50%        1.000000      1.000000       -0.059500       -0.759100
# 75%        1.000000      1.000000        0.355500       -0.241775
# max        1.000000      1.000000        5.603300        2.668000
#
#        acceleration_z        gyro_x        gyro_y        gyro_z
# count    88588.000000  88588.000000  88588.000000  88588.000000
# mean        -0.313956      0.004160      0.037203      0.022327
# std          0.486815      1.253423      1.198725      1.914423
# min         -3.753800     -4.430600     -7.464700     -9.480000
# ...

# %%
sns.set_style("whitegrid")
sns.countplot(x='activity', data=walk_run)
# Out:
# <Axes: xlabel='activity', ylabel='count'>

# %%
walk_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            88588 non-null  object
#  1   time            88588 non-null  object
#  2   username        88588 non-null  object
#  3   wrist           88588 non-null  int64
#  4   activity        88588 non-null  int64
#  5   acceleration_x  88588 non-null  float64
#  6   acceleration_y  88588 non-null  float64
#  7   acceleration_z  88588 non-null  float64
#  8   gyro_x          88588 non-null  float64
#  9   gyro_y          88588 non-null  float64
#  10  gyro_z          88588 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
walk_run.isnull().sum()
# Out:
# date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %%
walk_run.corr()
# Out:
# C:\Users\Gavi\AppData\Local\Temp\ipykernel_16680\3549493014.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   walk_run.corr()
#                    wrist  activity  acceleration_x  acceleration_y  \
# wrist           1.000000 -0.113404       -0.609579        0.087091
# activity       -0.113404  1.000000       -0.017747        0.639520
# acceleration_x -0.609579 -0.017747        1.000000       -0.265169
# acceleration_y  0.087091  0.639520       -0.265169        1.000000
# acceleration_z  0.323680 -0.192435       -0.552374        0.106220
# gyro_x         -0.022092  0.040856       -0.021705        0.010549
# gyro_y         -0.068403  0.012055       -0.004091        0.072170
# gyro_z          0.008796 -0.008106       -0.060849       -0.022994
#
#                 acceleration_z    gyro_x    gyro_y    gyro_z
# ...

# %%
walk_run_features = walk_run.loc[:, ~walk_run.columns.isin(["date", "time","username"])]

# %%
walk_run_features
# Out:
#        wrist  activity  acceleration_x  acceleration_y  acceleration_z  \
# 0          0         0          0.2650         -0.7814         -0.0076
# 1          0         0          0.6722         -1.1233         -0.2344
# 2          0         0          0.4399         -1.4817          0.0722
# 3          0         0          0.3031         -0.8125          0.0888
# 4          0         0          0.4814         -0.9312          0.0359
# ...      ...       ...             ...             ...             ...
# 88583      0         0          0.3084         -0.8376         -0.1327
# 88584      0         0          0.4977         -1.0027         -0.4397
# 88585      0         0          0.4587         -1.1780         -0.2827
# 88586      0         0          0.2590         -0.8582         -0.0759
# 88587      0         0          0.3140         -0.8008         -0.0911
#
#        gyro_x  gyro_y  gyro_z
# 0     -0.0590  0.0325 -2.9296
# 1     -0.1757  0.0208  0.1269
# ...

# %%
sns.heatmap(walk_run_features.corr())
# Out:
# <Axes: >

# %%
walk_run_features.corr()
# Out:
#                    wrist  activity  acceleration_x  acceleration_y  \
# wrist           1.000000 -0.113404       -0.609579        0.087091
# activity       -0.113404  1.000000       -0.017747        0.639520
# acceleration_x -0.609579 -0.017747        1.000000       -0.265169
# acceleration_y  0.087091  0.639520       -0.265169        1.000000
# acceleration_z  0.323680 -0.192435       -0.552374        0.106220
# gyro_x         -0.022092  0.040856       -0.021705        0.010549
# gyro_y         -0.068403  0.012055       -0.004091        0.072170
# gyro_z          0.008796 -0.008106       -0.060849       -0.022994
#
#                 acceleration_z    gyro_x    gyro_y    gyro_z
# wrist                 0.323680 -0.022092 -0.068403  0.008796
# activity             -0.192435  0.040856  0.012055 -0.008106
# acceleration_x       -0.552374 -0.021705 -0.004091 -0.060849
# acceleration_y        0.106220  0.010549  0.072170 -0.022994
# ...

# %%
walk = len(walk_run_features[walk_run_features["activity"] == 0].index)
walk
# Out:
# 44223

# %%
run = len(walk_run_features[walk_run_features["activity"] == 1].index)
run
# Out:
# 44365

# %%
left_hand = len(walk_run_features[walk_run_features["wrist"] == 0].index)
left_hand
# Out:
# 42330

# %%
right_hand = len(walk_run_features[walk_run_features["wrist"] == 1].index)
right_hand
# Out:
# 46258

# %%
sns.pairplot(walk_run_features[["acceleration_x", "acceleration_y", "acceleration_z", "wrist"]].sample(frac=.1).reset_index(drop=True), hue="wrist")

# %%
x = walk_run_features[["acceleration_x", "acceleration_y", "acceleration_z", "wrist", "gyro_x", "gyro_y", "gyro_z"]]
y = walk_run_features["activity"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,
                                                    y, 
                                                    test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.9709339503573428

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression( random_state =0)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
lr.score(X_test, y_test)
# Out:
# 0.8614967829326109

# %%
from sklearn.linear_model import LinearRegression
lir = LinearRegression()
lir.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lir.score(X_test, y_test)
# Out:
# 0.49444183349920146

# %%
from sk
